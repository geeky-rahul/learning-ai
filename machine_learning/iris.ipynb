# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('species', axis=1)
y = df['species']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn = KNeighborsClassifier(n_neighbors=13)

# %%
model_knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %%
model_knn.score(X_test, y_test)
# Out:
# 1.0

# %%
from sklearn.svm import SVC

# %%
model_svm = SVC(gamma= "auto")

# %%
model_svm.fit(X_train, y_train)
# Out:
# SVC(gamma='auto')

# %%
model_svm.score(X_test, y_test)
# Out:
# 1.0

# %% [markdown]
# # Grid Search CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
classifier = GridSearchCV((model_svm),{
    'C' : [1,10,20,30],
    'kernel' : ['linear', 'rbf']
}, cv=5, return_train_score = False)

# %%
classifier.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [1, 10, 20, 30], 'kernel': ['linear', 'rbf']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([0.00424514, 0.00380273, 0.00448823, 0.00775104, 0.00439315,
#         0.00492086, 0.00542097, 0.00442448]),
#  'std_fit_time': array([0.00141378, 0.00078918, 0.00090441, 0.00579001, 0.00087437,
#         0.00185406, 0.00124396, 0.00033709]),
#  'mean_score_time': array([0.00368042, 0.00280194, 0.00435681, 0.00327735, 0.00321441,
#         0.00318723, 0.00288939, 0.00344839]),
#  'std_score_time': array([0.00116458, 0.00031819, 0.00207559, 0.00081355, 0.00081395,
#         0.00079725, 0.00076747, 0.00109797]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20, 30, 30],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['linear', 'rbf', 'linear', 'rbf', 'linear', 'rbf',
#                     'linear', 'rbf'],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'linear'},
#   {'C': 1, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'rbf'},
#   {'C': 20, 'kernel': 'linear'},
#   {'C': 20, 'kernel': 'rbf'},
#   {'C': 30, 'kernel': 'linear'},
#   {'C': 30, 'kernel': 'rbf'}],
#  'split0_test_score': array([0.96666667, 0.96666667, 1.        , 0.96666667, 1.        ,
#         0.96666667, 1.        , 0.96666667]),
#  'split1_test_score': array([1., 1., 1., 1., 1., 1., 1., 1.]),
#  'split2_test_score': array([0.96666667, 0.96666667, 0.9       , 0.96666667, 0.9       ,
#         0.9       , 0.9       , 0.9       ]),
#  'split3_test_score': array([0.96666667, 0.96666667, 0.96666667, 0.96666667, 0.93333333,
#         0.96666667, 0.9       , 0.93333333]),
#  'split4_test_score': array([1., 1., 1., 1., 1., 1., 1., 1.]),
#  'mean_test_score': array([0.98      , 0.98      , 0.97333333, 0.98      , 0.96666667,
#         0.96666667, 0.96      , 0.96      ]),
#  'std_test_score': array([0.01632993, 0.01632993, 0.03887301, 0.01632993, 0.0421637 ,
#         0.03651484, 0.04898979, 0.03887301]),
#  'rank_test_score': array([1, 1, 4, 1, 6, 5, 7, 7], dtype=int32)}

# %%
results = pd.DataFrame(classifier.cv_results_)

# %%
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.004245      0.001414         0.003680        0.001165        1
# 1       0.003803      0.000789         0.002802        0.000318        1
# 2       0.004488      0.000904         0.004357        0.002076       10
# 3       0.007751      0.005790         0.003277        0.000814       10
# 4       0.004393      0.000874         0.003214        0.000814       20
# 5       0.004921      0.001854         0.003187        0.000797       20
# 6       0.005421      0.001244         0.002889        0.000767       30
# 7       0.004424      0.000337         0.003448        0.001098       30
#
#   param_kernel                         params  split0_test_score  \
# 0       linear   {'C': 1, 'kernel': 'linear'}           0.966667
# 1          rbf      {'C': 1, 'kernel': 'rbf'}           0.966667
# 2       linear  {'C': 10, 'kernel': 'linear'}           1.000000
# 3          rbf     {'C': 10, 'kernel': 'rbf'}           0.966667
# 4       linear  {'C': 20, 'kernel': 'linear'}           1.000000
# 5          rbf     {'C': 20, 'kernel': 'rbf'}           0.966667
# 6       linear  {'C': 30, 'kernel': 'linear'}           1.000000
# 7          rbf     {'C': 30, 'kernel': 'rbf'}           0.966667
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0                1.0           0.966667           0.966667                1.0
# 1                1.0           0.966667           0.966667                1.0
# 2                1.0           0.900000           0.966667                1.0
# 3                1.0           0.966667           0.966667                1.0
# 4                1.0           0.900000           0.933333                1.0
# 5                1.0           0.900000           0.966667                1.0
# 6                1.0           0.900000           0.900000                1.0
# 7                1.0           0.900000           0.933333                1.0
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.980000        0.016330                1
# 1         0.980000        0.016330                1
# 2         0.973333        0.038873                4
# 3         0.980000        0.016330                1
# 4         0.966667        0.042164                6
# 5         0.966667        0.036515                5
# 6         0.960000        0.048990                7
# 7         0.960000        0.038873                7

# %%
results[['param_C', 'param_kernel', 'mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1       linear         0.980000
# 1        1          rbf         0.980000
# 2       10       linear         0.973333
# 3       10          rbf         0.980000
# 4       20       linear         0.966667
# 5       20          rbf         0.966667
# 6       30       linear         0.960000
# 7       30          rbf         0.960000

# %% [markdown]
# # Random Search CV

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
classifier_r = RandomizedSearchCV((model_svm),{
    'C' : [1,10,20,30],
    'kernel' : ['linear', 'rbf']
}, n_iter= 4, cv=5, return_train_score = False)

# %%
classifier_r.fit(X, y)
# Out:
# RandomizedSearchCV(cv=5, estimator=SVC(gamma='auto'), n_iter=4,
#                    param_distributions={'C': [1, 10, 20, 30],
#                                         'kernel': ['linear', 'rbf']})

# %%
results = pd.DataFrame(classifier_r.cv_results_)

# %%
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_kernel  \
# 0       0.004349      0.001378         0.003497        0.001293       linear
# 1       0.003876      0.000831         0.002889        0.000415          rbf
# 2       0.006353      0.002170         0.006666        0.003728       linear
# 3       0.003751      0.000672         0.004614        0.001911          rbf
#
#    param_C                         params  split0_test_score  \
# 0       20  {'kernel': 'linear', 'C': 20}           1.000000
# 1       20     {'kernel': 'rbf', 'C': 20}           0.966667
# 2        1   {'kernel': 'linear', 'C': 1}           0.966667
# 3       10     {'kernel': 'rbf', 'C': 10}           0.966667
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0                1.0           0.900000           0.933333                1.0
# 1                1.0           0.900000           0.966667                1.0
# 2                1.0           0.966667           0.966667                1.0
# 3                1.0           0.966667           0.966667                1.0
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.966667        0.042164                4
# 1         0.966667        0.036515                3
# 2         0.980000        0.016330                1
# 3         0.980000        0.016330                1

# %%
results[['param_C', 'param_kernel', 'mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0       20       linear         0.966667
# 1       20          rbf         0.966667
# 2        1       linear         0.980000
# 3       10          rbf         0.980000
